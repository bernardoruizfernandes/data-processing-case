# %% [markdown]
# # Análise Simples de Comentários
#
# Objetivo: Descobrir quais amenities os usuários realmente mencionam e se falam bem ou mal delas.

# %%
import pandas as pd
import json
from anthropic import Anthropic
import os
import re

# %%
# Setup Claude API
from dotenv import load_dotenv
load_dotenv()  # Carrega .env file

client = Anthropic(
    api_key=os.environ.get("ANTHROPIC_API_KEY")
)

# Verificar se API key foi carregada
if not os.environ.get("ANTHROPIC_API_KEY"):
    print("❌ API Key não encontrada!")
    print("Opções:")
    print("1. Crie arquivo .env com: ANTHROPIC_API_KEY=sua-chave")
    print("2. Ou defina: export ANTHROPIC_API_KEY='sua-chave'")
    print("3. Ou cole diretamente no código (menos seguro)")
else:
    print("✅ API Key carregada com sucesso")
# Out:
# ✅ API Key carregada com sucesso

# %%
# Carregar dados - ESTRATÉGIA OTIMIZADA
reviews = pd.read_csv('data/processed/reviews.csv')
print(f"Total de reviews: {len(reviews)}")

# Amostra grande mas processável (respeitando limite de API)
sample_size = 5000  # Muito maior que antes
sample_reviews = reviews.sample(n=sample_size, random_state=42)
print(f"Amostra para análise: {len(sample_reviews)} comentários")
print(f"Estimativa de tempo: ~{sample_size/50:.1f} minutos (50 req/min limit)")
# Out:
# Total de reviews: 22376
# Amostra para análise: 5000 comentários
# Estimativa de tempo: ~100.0 minutos (50 req/min limit)

# %%
def clean_comment_for_api(comment):
    """Limpa e trunca comentário para eficiência máxima"""
    comment = re.sub(r'[\n\r\t]', ' ', str(comment))
    comment = comment.replace('"', "'")
    # Truncar para 100 caracteres (mais eficiente)
    return comment[:100]

def extract_amenities_batch(comments_batch):
    """Extrai amenities de MÚLTIPLOS comentários em uma única chamada API"""
    
    # Preparar prompt com múltiplos comentários
    comments_text = ""
    for i, comment in enumerate(comments_batch, 1):
        clean_comment = clean_comment_for_api(comment['comments'])
        comments_text += f"{i}. {clean_comment}\n"
    
    # Prompt ultra compacto para batch
    prompt = f"""Extract amenities from these comments:
{comments_text}

Return only valid JSON array:
[{{"comment":1,"amenity":"wifi","sentiment":"positive"}},{{"comment":1,"amenity":"kitchen","sentiment":"negative"}}]

Only extract physical amenities: wifi, kitchen, pool, AC, TV, washer, dryer, balcony, etc.
Ignore: location, host, apartment, building, neighborhood, price, service."""
    
    try:
        response = client.messages.create(
            model="claude-3-haiku-20240307",
            max_tokens=150,  # Aumentei um pouco para garantir resposta completa
            messages=[{"role": "user", "content": prompt}]
        )
        
        response_text = response.content[0].text.strip()
        
        # Tentar extrair JSON da resposta
        json_start = response_text.find('[')
        json_end = response_text.rfind(']') + 1
        
        if json_start != -1 and json_end > json_start:
            json_text = response_text[json_start:json_end]
            results = json.loads(json_text)
        else:
            print(f"Não foi possível encontrar JSON válido: {response_text[:100]}...")
            return []
        
        # Processar resultados
        processed_results = []
        for result in results:
            if isinstance(result, dict) and 'comment' in result and 'amenity' in result:
                comment_idx = result['comment'] - 1  # Converter para índice 0-based
                
                if 0 <= comment_idx < len(comments_batch):
                    original_comment = comments_batch[comment_idx]
                    
                    processed_results.append({
                        'item': result['amenity'],
                        'sentiment': result.get('sentiment', 'neutral'),
                        'listing_id': str(original_comment['listing_id']),
                        'review_id': str(original_comment['id'])
                    })
        
        return processed_results
        
    except json.JSONDecodeError as e:
        print(f"Erro JSON: {e}")
        print(f"Resposta recebida: {response_text[:200]}...")
        return []
    except Exception as e:
        print(f"Erro API: {e}")
        return []

# Teste com dados reais
print("Testando função corrigida...")
test_batch = sample_reviews.head(2).to_dict('records')
test_result = extract_amenities_batch(test_batch)
print(f"Resultado: {len(test_result)} amenities extraídas")
for r in test_result:
    print(f"  - {r['item']}: {r['sentiment']}")
# Out:
# Testando função corrigida...
# Resultado: 1 amenities extraídas
#   - kitchen: positive

# %%
# Processar comentários em LOTES - VERSÃO OTIMIZADA
import time
from datetime import datetime

all_amenities = []
errors_count = 0
processed_count = 0
batch_size = 10  # 10 comentários por requisição

# Converter para lista de dicionários para batch processing
comments_list = sample_reviews.to_dict('records')

print(f"Iniciando processamento em lotes de {batch_size} comentários...")
print(f"Total de lotes: {len(comments_list)//batch_size}")
print(f"Estimativa: ~{len(comments_list)//batch_size/50:.1f} minutos\n")

start_time = time.time()

# Processar em batches
for i in range(0, len(comments_list), batch_size):
    batch = comments_list[i:i+batch_size]
    batch_num = i//batch_size + 1
    
    print(f"Lote {batch_num}/{len(comments_list)//batch_size} ({len(batch)} comentários)...", end=' ')
    
    try:
        # Timing preciso: 1.2 segundos entre requisições (50 req/min)
        if batch_num > 1:  # Não esperar no primeiro lote
            time.sleep(1.2)
        
        batch_amenities = extract_amenities_batch(batch)
        all_amenities.extend(batch_amenities)
        processed_count += len(batch)
        
        print(f"✅ {len(batch_amenities)} amenities extraídas")
        
        # Checkpoint a cada 50 requisições (500 comentários)
        if batch_num % 50 == 0:
            checkpoint_file = f'data/processed/checkpoint_batch_{batch_num}.json'
            with open(checkpoint_file, 'w', encoding='utf-8') as f:
                json.dump(all_amenities, f, ensure_ascii=False, indent=2)
            
            elapsed = time.time() - start_time
            rate = processed_count / elapsed * 60  # comentários por minuto
            print(f"\n📊 Checkpoint {batch_num}: {len(all_amenities)} amenities | {rate:.0f} comentários/min")
    
    except Exception as e:
        errors_count += 1
        print(f"❌ Erro: {e}")
        continue

# Estatísticas finais
elapsed_time = time.time() - start_time
rate = processed_count / elapsed_time * 60

print(f"\n{'='*60}")
print(f"PROCESSAMENTO CONCLUÍDO!")
print(f"{'='*60}")
print(f"📊 Processados: {processed_count} comentários em {elapsed_time:.1f}s")
print(f"⚡ Taxa: {rate:.0f} comentários/minuto")
print(f"🎯 Amenities extraídas: {len(all_amenities)}")
print(f"❌ Erros: {errors_count}")
print(f"✅ Taxa de sucesso: {(1-errors_count/(len(comments_list)//batch_size))*100:.1f}%")

# Salvar resultados finais
try:
    with open('data/processed/amenities_from_comments.json', 'w', encoding='utf-8') as f:
        json.dump(all_amenities, f, ensure_ascii=False, indent=2)
    
    if all_amenities:
        df_amenities = pd.DataFrame(all_amenities)
        df_amenities.to_csv('data/processed/amenities_from_comments.csv', index=False, encoding='utf-8')
        print(f"💾 Dados salvos: amenities_from_comments.csv ({len(df_amenities)} linhas)")
    
except Exception as e:
    print(f"❌ Erro ao salvar: {e}")
# Out:
# Iniciando processamento em lotes de 10 comentários...
# Total de lotes: 500
# Estimativa: ~10.0 minutos
#
# Lote 1/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 2/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 3/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 4/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 5/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 6/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 7/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 8/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 9/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 10/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 11/500 (10 comentários)... Não foi possível encontrar JSON válido: [
# {"comment":1,"amenity":"location","sentiment":"positive"},
# {"comment":1,"amenity":"security","sent...
# ✅ 0 amenities extraídas
# Lote 12/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 13/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 14/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 15/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 16/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 17/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 18/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 19/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 20/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 21/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array of extracted amenities from the given comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 22/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 23/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 24/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     "amenity": "kitchen"...
# ✅ 0 amenities extraídas
# Lote 25/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "localização",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 26/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 27/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 28/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 29/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 30/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 31/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "gated apart hotel",
#     "sentiment": "positive"
#   },
#   {
#    ...
# ✅ 0 amenities extraídas
# Lote 32/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 33/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 34/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 35/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 36/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "cleaning",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 37/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 38/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 39/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 40/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 41/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 42/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "doorman",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 43/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 44/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 45/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean space",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 46/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "tv"
#   },
#   {
#     "comment": 4,
#     "amenity": "bed"
#   },
#   {...
# ✅ 0 amenities extraídas
# Lote 47/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 48/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 49/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 50/500 (10 comentários)... ✅ 1 amenities extraídas
#
# 📊 Checkpoint 50: 73 amenities | 247 comentários/min
# Lote 51/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "praia",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 52/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 53/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "walk to best restaurants",
#     "sentiment": "positive"
#   },
# ...
# ✅ 0 amenities extraídas
# Lote 54/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 55/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 56/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 57/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 58/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 59/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 60/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 61/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 62/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 63/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 64/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 65/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 66/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "space",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 67/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 68/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "location"
#   },
#   {
#     "comment": 3,
#     "amenity": "locatio...
# ✅ 0 amenities extraídas
# Lote 69/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 2,
#     ...
# ✅ 0 amenities extraídas
# Lote 70/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 71/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "supermarket",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 72/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 73/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 74/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 75/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "bars",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 76/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 77/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 78/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 79/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 80/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "view"
#   },
#   {
#     "comment": 3,
#     "amenity": "apartment"
# ...
# ✅ 0 amenities extraídas
# Lote 81/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "metro",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 82/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 83/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 84/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 85/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 86/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 87/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "shopping",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 88/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 89/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 90/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment"
#   },
#   {
#     "comment": 1,
#     "amenity": "clean"...
# ✅ 0 amenities extraídas
# Lote 91/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 92/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 93/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 94/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 95/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 96/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 97/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 98/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "anfitrião",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 99/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 100/500 (10 comentários)... ✅ 2 amenities extraídas
#
# 📊 Checkpoint 100: 130 amenities | 242 comentários/min
# Lote 101/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 102/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 103/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "balcony",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 104/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "AC",
#     "sentiment": "negative"
#   },
#   {
#     "comment": 6,
# ...
# ✅ 0 amenities extraídas
# Lote 105/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "well decorated apartment",
#     "sentiment": "positive"
#   },
# ...
# ✅ 0 amenities extraídas
# Lote 106/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 107/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 108/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment"
#   },
#   {
#     "comment": 2,
#     "amenity": "locati...
# ✅ 0 amenities extraídas
# Lote 109/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "spacious",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 110/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 111/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 112/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 113/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 114/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "building"
#   },
#   {
#     "comment": 3,
#     "amenity": "apartme...
# ✅ 0 amenities extraídas
# Lote 115/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 116/500 (10 comentários)... Não foi possível encontrar JSON válido: [
# {"comment":2,"amenity":"wifi","sentiment":"positive"},
# {"comment":3,"amenity":"wifi","sentiment":"...
# ✅ 0 amenities extraídas
# Lote 117/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 118/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 119/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 120/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "well-located"
#   },
#   {
#     "comment": 2,
#     "amenity": "all...
# ✅ 0 amenities extraídas
# Lote 121/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 122/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach"
#   },
#   {
#     "comment": 2,
#     "amenity": "view"
#   },...
# ✅ 0 amenities extraídas
# Lote 123/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "acomodações"
#   },
#   {
#     "comment": 2,
#     "amenity": "full...
# ✅ 0 amenities extraídas
# Lote 124/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 125/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 126/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 127/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "fully furnished",
#     "sentiment": "positive"
#   },
#   {
#     "...
# ✅ 0 amenities extraídas
# Lote 128/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 129/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 130/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 131/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 132/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "stylish"
#   },
#   {
#     "comment": 1,
#     "amenity": "thoughtf...
# ✅ 0 amenities extraídas
# Lote 133/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 4,
#     "amenity": "view"
#   },
#   {
#     "comment": 5,
#     "amenity": "decor"
#   },...
# ✅ 0 amenities extraídas
# Lote 134/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 135/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 136/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 137/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 138/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 139/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach"
#   },
#   {
#     "comment": 1,
#     "amenity": "restaurant...
# ✅ 0 amenities extraídas
# Lote 140/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "market",
#     "sentiment": "positive"
#   },
#   {
#     "comment":...
# ✅ 0 amenities extraídas
# Lote 141/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 142/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 143/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 144/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 145/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 146/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 147/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 148/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 149/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 150/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "praia",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
#
# 📊 Checkpoint 150: 185 amenities | 241 comentários/min
# Lote 151/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 152/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "air conditioning",
#     "sentiment": "positive"
#   },
#   {
#     ...
# ✅ 0 amenities extraídas
# Lote 153/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 154/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 4...
# ✅ 0 amenities extraídas
# Lote 155/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 156/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 157/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 158/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array of extracted amenities from the comments:
#
# [
#   {"comment":1,"amenity":"beach"...
# ✅ 0 amenities extraídas
# Lote 159/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 160/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 161/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "view",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 162/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 163/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "champanhe"
#   },
#   {
#     "comment": 2,
#     "amenity": "locali...
# ✅ 0 amenities extraídas
# Lote 164/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 6,
#     ...
# ✅ 0 amenities extraídas
# Lote 165/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "ac",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2,
# ...
# ✅ 0 amenities extraídas
# Lote 166/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 167/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 168/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 169/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 170/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 171/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 172/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 4,
#     "amenity": "bed linen",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 173/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 174/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 175/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 176/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 177/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean"
#   },
#   {
#     "comment": 2,
#     "amenity": "clean"
#   }...
# ✅ 0 amenities extraídas
# Lote 178/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 179/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 180/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 181/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 182/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 183/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "new",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 3,...
# ✅ 0 amenities extraídas
# Lote 184/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 185/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 186/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 187/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 188/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 189/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 190/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 191/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 192/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 193/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 194/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 195/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "items that facilitated our stay",
#     "sentiment": "positive...
# ✅ 0 amenities extraídas
# Lote 196/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurantes",
#     "sentiment": "positive"
#   },
#   {
#     "com...
# ✅ 0 amenities extraídas
# Lote 197/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 198/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach"
#   },
#   {
#     "comment": 4,
#     "amenity": "nespresso_...
# ✅ 0 amenities extraídas
# Lote 199/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "estrutur"
#   },
#   {
#     "comment": 2,
#     "amenity": "superma...
# ✅ 0 amenities extraídas
# Lote 200/500 (10 comentários)... ✅ 3 amenities extraídas
#
# 📊 Checkpoint 200: 245 amenities | 238 comentários/min
# Lote 201/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 202/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 203/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 204/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 205/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 206/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 207/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 208/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array of extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     "ameni...
# ✅ 0 amenities extraídas
# Lote 209/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the extracted amenities from the comments in a valid JSON array:
#
# [
#   {
#     "comment": 1,
#   ...
# ✅ 0 amenities extraídas
# Lote 210/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartamento",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 211/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 212/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 213/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean"
#   },
#   {
#     "comment": 7,
#     "amenity": "complete"
# ...
# ✅ 0 amenities extraídas
# Lote 214/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 215/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 6,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 216/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 217/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 218/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 219/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 220/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 221/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 222/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 223/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 224/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 225/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 226/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 227/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 228/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 229/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants"
#   },
#   {
#     "comment": 1,
#     "amenity": "shop...
# ✅ 0 amenities extraídas
# Lote 230/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 231/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 232/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach"
#   },
#   {
#     "comment": 6,
#     "amenity": "grocery st...
# ✅ 0 amenities extraídas
# Lote 233/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 234/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "cleaning service",
#     "sentiment": "positive"
#   },
#   {
#     ...
# ✅ 0 amenities extraídas
# Lote 235/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 236/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 7,
#     "amenity": "bars",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 7...
# ✅ 0 amenities extraídas
# Lote 237/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 238/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 239/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 6,
#     "amenity": "aparatos"
#   },
#   {
#     "comment": 7,
#     "amenity": "bar",
#  ...
# ✅ 0 amenities extraídas
# Lote 240/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 241/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 242/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 243/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 3...
# ✅ 0 amenities extraídas
# Lote 244/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 245/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 246/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 247/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 248/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 249/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 250/500 (10 comentários)... ✅ 1 amenities extraídas
#
# 📊 Checkpoint 250: 306 amenities | 150 comentários/min
# Lote 251/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 252/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 253/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "equipado"
#   },
#   {
#     "comment": 1,
#     "amenity": "mobilia...
# ✅ 0 amenities extraídas
# Lote 254/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 255/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 256/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 257/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 258/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 259/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "location"
#   },
#   {
#     "comment": 3,
#     "amenity": "locatio...
# ✅ 0 amenities extraídas
# Lote 260/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 261/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 262/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "arejado",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 263/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 264/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 265/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "view",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 3...
# ✅ 0 amenities extraídas
# Lote 266/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "praia"
#   },
#   {
#     "comment": 2,
#     "amenity": "ar condici...
# ✅ 0 amenities extraídas
# Lote 267/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 268/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 269/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 270/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 271/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "Comodidad"
#   },
#   {
#     "comment": 3,
#     "amenity": "apartm...
# ✅ 0 amenities extraídas
# Lote 272/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 273/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 274/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 275/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 276/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 277/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 278/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 279/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 280/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 281/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 282/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean"
#   },
#   {
#     "comment": 3,
#     "amenity": "modern"
#   ...
# ✅ 0 amenities extraídas
# Lote 283/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array of extracted amenities from the comments:
#
# [
#   {
#     "comment": 2,
#     "ameni...
# ✅ 0 amenities extraídas
# Lote 284/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 285/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 286/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 287/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 288/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 289/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 290/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 291/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 292/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 293/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 294/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "conforto",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 295/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "flat"
#   },
#   {
#     "comment": 3,
#     "amenity": "early check...
# ✅ 0 amenities extraídas
# Lote 296/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "playa"
#   },
#   {
#     "comment": 1,
#     "amenity": "restaurant...
# ✅ 0 amenities extraídas
# Lote 297/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 298/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 299/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "flexible check-in",
#     "sentiment": "positive"
#   },
#   {
#    ...
# ✅ 0 amenities extraídas
# Lote 300/500 (10 comentários)... ✅ 2 amenities extraídas
#
# 📊 Checkpoint 300: 376 amenities | 160 comentários/min
# Lote 301/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 302/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 3,
#     ...
# ✅ 0 amenities extraídas
# Lote 303/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 304/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "shopping"
#   },
#   {
#     "comment": 2,
#     "amenity": "restaur...
# ✅ 0 amenities extraídas
# Lote 305/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 306/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 307/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 308/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "views"
#   },
#   {
#     "comment": 2,
#     "amenity": "pool"
#   },...
# ✅ 0 amenities extraídas
# Lote 309/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 310/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 311/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 312/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 313/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 314/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 315/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 316/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 317/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 318/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 319/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the extracted JSON array with the physical amenities from the comments:
#
# [
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 320/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "negative"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 321/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 322/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "bed",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 4,...
# ✅ 0 amenities extraídas
# Lote 323/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 324/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "security",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 325/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 326/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 6,
#     "amenity": "clean"
#   },
#   {
#     "comment": 6,
#     "amenity": "location"
# ...
# ✅ 0 amenities extraídas
# Lote 327/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 2...
# ✅ 0 amenities extraídas
# Lote 328/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "ótimos resta"
#   },
#   {
#     "comment": 2,
#     "amenity": "per...
# ✅ 0 amenities extraídas
# Lote 329/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 330/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 5,
#     "amenity": "shampoo",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 331/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 332/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 333/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 334/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "metro",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 335/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 336/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach"
#   },
#   {
#     "comment": 1,
#     "amenity": "restaurant...
# ✅ 0 amenities extraídas
# Lote 337/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 5,
#     "amenity": "fruit",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 338/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "space"
#   },
#   {
#     "comment": 2,
#     "amenity": "balcony"
#  ...
# ✅ 0 amenities extraídas
# Lote 339/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "zona"
#   },
#   {
#     "comment": 2,
#     "amenity": "vista",
#    ...
# ✅ 0 amenities extraídas
# Lote 340/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 341/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 342/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "vista linda",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 343/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 344/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 345/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 346/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array containing the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 347/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 348/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 349/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 350/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
#
# 📊 Checkpoint 350: 427 amenities | 167 comentários/min
# Lote 351/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 352/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "metro"
#   },
#   {
#     "comment": 3,
#     "amenity": "flat"
#   },...
# ✅ 0 amenities extraídas
# Lote 353/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 354/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "excelente ubicación"
#   },
#   {
#     "comment": 3,
#     "amenity...
# ✅ 0 amenities extraídas
# Lote 355/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 356/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "view",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 4...
# ✅ 0 amenities extraídas
# Lote 357/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "comfortable"
#   },
#   {
#     "comment": 5,
#     "amenity": "well...
# ✅ 0 amenities extraídas
# Lote 358/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 359/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 360/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "balcony",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 361/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 362/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 363/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 364/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "cleaning",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 365/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 366/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "view"
#   },
#   {
#     "comment": 2,
#     "amenity": "security",
# ...
# ✅ 0 amenities extraídas
# Lote 367/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 368/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 369/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 370/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 371/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 372/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 373/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 374/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 375/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 376/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 377/500 (10 comentários)... ✅ 5 amenities extraídas
# ...
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 380/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 381/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 382/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 383/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 384/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 385/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "limpo",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 386/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "safe area"
#   },
#   {
#     "comment": 2,
#     "amenity": "close ...
# ✅ 0 amenities extraídas
# Lote 387/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 388/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 389/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 390/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 391/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 392/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 393/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 394/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 395/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 396/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 397/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 398/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 399/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 400/500 (10 comentários)... ✅ 4 amenities extraídas
#
# 📊 Checkpoint 400: 497 amenities | 173 comentários/min
# Lote 401/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 402/500 (10 comentários)... Erro JSON: Expecting ',' delimiter: line 25 column 6 (char 344)
# Resposta recebida: Here is the JSON array with the extracted amenities from the comments:
#
# [
#   {
#     "comment": 1,
#     "amenity": [
#       "supermarket",
#       "pharmacy",
#       "bars",
#       "restaurants",
#       "shops"...
# ✅ 0 amenities extraídas
# Lote 403/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "shopping",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 404/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 405/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 406/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 407/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "balcony",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 408/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 409/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 410/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment"
#   },
#   {
#     "comment": 3,
#     "amenity": "single...
# ✅ 0 amenities extraídas
# Lote 411/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "mall",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 412/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 413/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "metro",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 414/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 415/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 416/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beds",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 417/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "well-equipped",
#     "sentiment": "positive"
#   },
#   {
#     "co...
# ✅ 0 amenities extraídas
# Lote 418/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment",
#     "sentiment": "positive"
#   },
#   {
#     "commen...
# ✅ 0 amenities extraídas
# Lote 419/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 420/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array with the extracted physical amenities from the comments:
#
# [
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 421/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 422/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 423/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen"
#   },
#   {
#     "comment": 2,
#     "amenity": "items fo...
# ✅ 0 amenities extraídas
# Lote 424/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 425/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 426/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 427/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 428/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 429/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 430/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "grocery store"
#   },
#   {
#     "comment": 2,
#     "amenity": "be...
# ✅ 0 amenities extraídas
# Lote 431/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "supermarket",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 432/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment"
#   },
#   {
#     "comment": 2,
#     "amenity": "furnit...
# ✅ 0 amenities extraídas
# Lote 433/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 434/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 435/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 436/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "coffee machine",
#     "sentiment": "positive"
#   },
#   {
#     "c...
# ✅ 0 amenities extraídas
# Lote 437/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "view",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 6...
# ✅ 0 amenities extraídas
# Lote 438/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "apartment"
#   },
#   {
#     "comment": 1,
#     "amenity": "clean"...
# ✅ 0 amenities extraídas
# Lote 439/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 440/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 3,
#     "amenity": "table",
#     "sentiment": "negative"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 441/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 442/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "bed"
#   },
#   {
#     "comment": 1,
#     "amenity": "bed"
#   },
#   ...
# ✅ 0 amenities extraídas
# Lote 443/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 444/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 445/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 446/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 447/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 448/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 449/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "comfortable"
#   },
#   {
#     "comment": 2,
#     "amenity": "lamp...
# ✅ 0 amenities extraídas
# Lote 450/500 (10 comentários)... ✅ 1 amenities extraídas
#
# 📊 Checkpoint 450: 553 amenities | 178 comentários/min
# Lote 451/500 (10 comentários)... ✅ 6 amenities extraídas
# Lote 452/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "view",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 3...
# ✅ 0 amenities extraídas
# Lote 453/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 454/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 455/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "restaurant",
#     "sentiment": "positive"
#   },
#   {
#     "comme...
# ✅ 0 amenities extraídas
# Lote 456/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "beach",
#     "sentiment": "positive"
#   },
#   {
#     "comment": ...
# ✅ 0 amenities extraídas
# Lote 457/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 5,
#     "amenity": "pharmacy",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 458/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 459/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 460/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "comfortable"
#   },
#   {
#     "comment": 2,
#     "amenity": "supe...
# ✅ 0 amenities extraídas
# Lote 461/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 462/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 463/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 464/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "restaurants",
#     "sentiment": "positive"
#   },
#   {
#     "comm...
# ✅ 0 amenities extraídas
# Lote 465/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "location",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 466/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "spacious"
#   },
#   {
#     "comment": 1,
#     "amenity": "comfort...
# ✅ 0 amenities extraídas
# Lote 467/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 468/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 469/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 470/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 471/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 472/500 (10 comentários)... Não foi possível encontrar JSON válido: Here is the JSON array of extracted amenities from the given comments:
#
# [
#   {
#     "comment": 1,
#     ...
# ✅ 0 amenities extraídas
# Lote 473/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 474/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen"
#   },
#   {
#     "comment": 2,
#     "amenity": "wifi"
#   ...
# ✅ 0 amenities extraídas
# Lote 475/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 476/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "bedding",
#     "sentiment": "negative"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 477/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "clean"
#   },
#   {
#     "comment": 1,
#     "amenity": "organized"...
# ✅ 0 amenities extraídas
# Lote 478/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 479/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 480/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "portero 24 h"
#   },
#   {
#     "comment": 2,
#     "amenity": "dis...
# ✅ 0 amenities extraídas
# Lote 481/500 (10 comentários)... ✅ 2 amenities extraídas
# Lote 482/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 483/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "wifi",
#     "sentiment": "positive"
#   },
#   {
#     "comment": 1...
# ✅ 0 amenities extraídas
# Lote 484/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "refrigerator",
#     "sentiment": "negative"
#   },
#   {
#     "com...
# ✅ 0 amenities extraídas
# Lote 485/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 486/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 487/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 488/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 489/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 490/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 491/500 (10 comentários)... ✅ 4 amenities extraídas
# Lote 492/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 1,
#     "amenity": "check-in",
#     "sentiment": "positive"
#   },
#   {
#     "comment...
# ✅ 0 amenities extraídas
# Lote 493/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 494/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 495/500 (10 comentários)... ✅ 1 amenities extraídas
# Lote 496/500 (10 comentários)... ✅ 3 amenities extraídas
# Lote 497/500 (10 comentários)... ✅ 5 amenities extraídas
# Lote 498/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 499/500 (10 comentários)... Não foi possível encontrar JSON válido: [
#   {
#     "comment": 2,
#     "amenity": "kitchen",
#     "sentiment": "positive"
#   },
#   {
#     "comment"...
# ✅ 0 amenities extraídas
# Lote 500/500 (10 comentários)... ✅ 3 amenities extraídas
#
# 📊 Checkpoint 500: 621 amenities | 182 comentários/min
#
# ============================================================
# PROCESSAMENTO CONCLUÍDO!
# ============================================================
# 📊 Processados: 5000 comentários em 1648.2s
# ⚡ Taxa: 182 comentários/minuto
# 🎯 Amenities extraídas: 621
# ❌ Erros: 0
# ✅ Taxa de sucesso: 100.0%
# 💾 Dados salvos: amenities_from_comments.csv (621 linhas)
